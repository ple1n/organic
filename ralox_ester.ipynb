# %%
using Unitful

# %%
m_ralox = 40u"mg"
# Out:
# 40 mg

# %%
mw_ralox = 473u"g/mol"
pm_cl = 274u"g/mol"
# Out:
# 274 g mol^-1

# %%
m_cl = (pm_cl / mw_ralox) * m_ralox
# Out:
# 23.17124735729387 mg

# %%
# Ralox-mono-palmitate

# %% [markdown]
# After 8 hours the powder turned fully white. Probably all turned into di-ester

# %% [markdown]
# Good solubility in ethanol
#
# DMSO > Ethanol > EtAcetate

# %%
m_yield = 122u"mg"
# Out:
# 122 mg

# %% [markdown]
# Step: Inject 20mg Ralox -> 60mg Ralox-di

# %% [markdown]
# I ended up adding all three solvents, with DMSO and ethanol for solubilizing, ethanol and etAcetate for better flowability
#
# Ethanol also scavenges some remaining acyl chloride

# %% [markdown]
# Experiment has shown, 190C (heat pad) for 30mins caused degrdadation, turning brown

# %%
ralox = 473u"g/mol"
mw_di = ralox - 2*17u"g/mol" + 2*255u"g/mol"; mw_di
# Out:
# 949 g mol^-1

# %% [markdown]
# In this attempt, Raloxifene freebase was obtained by phase extraction with 2meTHF and NaHCO3. Ralox didn't show good solubility in the organic phase. It got freebased and immediately crystalized back in the organic phase.
#
# This is ok because I got the freebase anyway, but messy due to non dissolution.

# %% [markdown]
# Heat pad at 150C for 30mins still caused slight degradation. I think it precipitated out less soluble degradation products

# %% [markdown]
# Pending Experiment: Sterile filtration with 0.5um TiO2 semi-spherical particles, through 0.22um pore filter. Verify with microscope.

# %% [markdown]
# Pending Experiment: 2meTHF-water biphase Triethylamine freebasing Raloxifene. TEA-HCl is insoluble in THF, it should precipitate out into water phase

# %% [markdown]
# Task: Evaluate Ralox-di solubility in EtAc

# %% [markdown]
# Added 5x300uL = 1.5mL to a tube of 1mg Ralox-Dipalmitate. Still, murky suspension.

# %% [markdown]
# Solubility < 0.6mL/mg

# %% [markdown]
# Centrifuged, showing little sediment, which means complete dissolution is close.

# %% [markdown]
# The point being a lot of impurities can dissolve in EtAC
#
# Palmitic acid: 10.7 g/100 g

# %% [markdown]
# Test: Palmitoyl chloride solubility in EtAc

# %% [markdown]
# 45mg in 300uL EtAc. Complete dissolution throughout the process
#
# I bet its miscible.

# %% [markdown]
# I was using 2me-thf as primary solvent for reaction, because it seemed Ralox-freebase wasn't dissolving well in EtAc, which made the reaction slow.

# %% [markdown]
# I added a bit of Ralox-Hcl to that tube (PalCl in EtAc)

# %% [markdown]
# Ralox is soluble in EtAc. Adding PalCl should produce ester and precipitate out. The pro of this method is it has visible indication

# %% [markdown]
# Ralox-HCl has distinct red fluorecence under 365nm. Di-ester doesnt have it.

# %% [markdown]
# The EtAc solvent based reaction doesnt seem to proceeed

# %% [markdown]
# Direct Ralox-Hcl esterification method is probably dead I gave up
#
# Ralox is yellow and shows yellow fluorecence, Ralox-Hcl is off white and has red fluorecence.
#
# Both form good suspensions in EtAc.
#
# Ralox seems to have higher solubility in EtAc too.

# %% [markdown]
# I ended up doing a EtAc-Water biphase. 2MeTHF turned out to form a stable emulsion with water with TEA.
#
# TEA is perfect here it increased ralox's sol in EtAc. Freebasing is easily verified with 365nm. No red fluorecence

# %% [markdown]
# A convenient thing is, after adding more water, extracting it, adding more, ie washing, the TEA in the EtAc gets removed, and the Ralox precipitated as clearly edged solid

# %%
tube = 2.3758u"mg"
# Out:
# 2.3758 mg

# %% [markdown]
# Before reacting, the ralox is dried and weighed

# %%
ralox_hcl = 140u"mg"
# Out:
# 140 mg

# %% [markdown]
# TEA is useless.
#
# The protocol to freebase Ralox is as such.
#
# Ralox-HCl is off white powder. Preapre EtAc-Water two phase system. Add some NaHCO3.
#
# Stir the liquid until all powder turns yellow (Ralox is bright yellow), and no sign of red fluorecence.
#
# Dry up.

# %% [markdown]
# I believe the mechanism is, Ralox-HCl dissolves in water phase, gets deprotonated, migrates into oragnic phase, and immediately precipitates out.

# %%
ralox = 8.4u"mg"
# Out:
# 8.4 mg

# %% [markdown]
# 50ul pal and ralox in EtAc.
#
# heated to 100C and make it react to off water suspension

# %% [markdown]
# It produced light-yellow powder that has light yellow fluorecence. Note, in the same solvent, Ralox freebase is dim under 365nm
#
# Palmitates in general have quite bright fluorecence. (Ethyl palmitate, palmitic acid all showed bright fluorecence.)

# %% [markdown]
# I compared it with dipalmitate sample, which was obtained by 2methf. Dipalmitate is visibly whiter.

# %% [markdown]
# Pal-Cl has bp of 90C. I will evaporate it off along with EtAc

# %% [markdown]
# I will keep reaction over night to see if time is a variable over dipalmitate/palmitate formation

# %% [markdown]
# If this monopalmitic reaction works, it should be like, Ralox dissolves in the Pal-Cl-EtAc solution, gets esterified, and precipitates back out (as shown above).
#
# The solubility shouldn't be a problem as the solution only acts as a temporary medium.

# %% [markdown]
# Ralox-Monopalmitate precipitating should limit its further esterification, which may explain the mono-ester formation

# %% [markdown]
# Question: How do I know its not a homogenous mixture of Ralox, and Ralox-monopalmitate
#
# probably with melting point test

# %% [markdown]
# Next batch

# %%
tube = 2.3755u"mg"
m_ralox = 29.1u"mg"
# Out:
# 29.1 mg

# %%
n_ralox = m_ralox / ralox |> u"mol"
# Out:
# DimensionError: mol and 3.4642857142857144 are not dimensionally compatible.
#
#
#
# Stacktrace:
#
#  [1] uconvert(a::Unitful.FreeUnits{(mol,), 𝐍, nothing}, x::Float64)
#
#    @ Unitful ~/.julia/packages/Unitful/nwwOk/src/conversion.jl:101
#
#  [2] (::Unitful.FreeUnits{(mol,), 𝐍, nothing})(x::Float64)
#
#    @ Unitful ~/.julia/packages/Unitful/nwwOk/src/types.jl:110
#
#  [3] |>(x::Float64, f::Unitful.FreeUnits{(mol,), 𝐍, nothing})
#
#    @ Base ./operators.jl:926
#
#  [4] top-level scope
#
#    @ /b/by_projects/notes_a/organic/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_Y100sZmlsZQ==.jl:1

# %%
palmi = 274u"g/mol"
# Out:
# 274 g mol^-1

# %%
m_pal = n_ralox * palmi
# Out:
# UndefVarError: `n_ralox` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ /b/by_projects/notes_a/organic/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_Y102sZmlsZQ==.jl:1

# %%
rho_palmi = 0.9u"g/ml"
v_pal = m_pal / rho_palmi
# Out:
# UndefVarError: `m_pal` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ /b/by_projects/notes_a/organic/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_Y103sZmlsZQ==.jl:2

# %% [markdown]
# As usual, 50 uL of pal-cl will be added, in excess

# %% [markdown]
# When the ralox ester forms it can be noticed it better suspends in EtAc, which is expected due to increased lipophilicity

# %% [markdown]
# Probably a mixture of monoester and diester ultimately. With sufficient reaction time and Pal-Cl, at least it can be guaranteed the base ralox all gets converted.

# %% [markdown]
# Tube was put on 70C heat pad over 30min. It turned whiter over time.
#
# The ester has a characteristic feature that it is milky white, forming a very milky suspension
#
# It's opaque. The same saturated Ralox suspension in EtAc is transparent.

# %% [markdown]
# In EtAc, Ralox-freebase hardly forms a suspension. It settles at the bottom quickly as bright yellow substance.
#
# There is no such sediment in the tube. So it can be proved that Ralox-freebase has been converted to mono-ester and di-ester.

# %% [markdown]
# Liquid was transferred and centrifuged. Some bit was loss so gravimetric method will be unusable.

# %% [markdown]
# Yield was lost due to repeated transfer

# %% [markdown]
# Will do a large batch

# %%
tube = 10.401u"mg"
m_ralox = 94.2u"mg"
# Out:
# 94.2 mg

# %%
function equi_pal(m_ralox)
    n = m_ralox / ralox
    println("m", palmi * n)
    println("v", (palmi * n / 0.9u"g/ml" |> u"mL"))
end
# Out:
# equi_pal (generic function with 1 method)

# %%
equi_pal(m_ralox)
# Out:
# m3072.7142857142853 g mol^-1
# DimensionError: mL and mL mol^-1 are not dimensionally compatible.
#
#
#
# Stacktrace:
#
#  [1] #s103#141
#
#    @ ~/.julia/packages/Unitful/nwwOk/src/conversion.jl:28 [inlined]
#
#  [2] var"#s103#141"(::Any, s::Any, t::Any)
#
#    @ Unitful ./none:0
#
#  [3] (::Core.GeneratedFunctionStub)(::UInt64, ::LineNumberNode, ::Any, ::Vararg{Any})
#
#    @ Core ./boot.jl:707
#
#  [4] uconvert(a::Unitful.FreeUnits{(mL,), 𝐋^3, nothing}, x::Quantity{Float64, 𝐋^3 𝐍^-1, Unitful.FreeUnits{(mL, mol^-1), 𝐋^3 𝐍^-1, nothing}})
#
#    @ Unitful ~/.julia/packages/Unitful/nwwOk/src/conversion.jl:93
#
#  [5] FreeUnits
#
#    @ ~/.julia/packages/Unitful/nwwOk/src/types.jl:110 [inlined]
#
#  [6] |>(x::Quantity{Float64, 𝐋^3 𝐍^-1, Unitful.FreeUnits{(mL, mol^-1), 𝐋^3 𝐍^-1, nothing}}, f::Unitful.FreeUnits{(mL,), 𝐋^3, nothing})
#
#    @ Base ./operators.jl:926
#
#  [7] equi_pal(m_ralox::Quantity{Float64, 𝐌, Unitful.FreeUnits{(mg,), 𝐌, nothing}})
#
# ...

# %% [markdown]
# final palcl added, 71mg

# %%
daily_dose = 60u"mg" * 0.02

# this is the dose calculated based on oral bio-availability
# Out:
# 1.2 mg

# %%
m_ralox / daily_dose
# Out:
# 78.5

# %% [markdown]
# 350uL of 2methf was added to accelerate reaction, by increasing solubility

# %% [markdown]
# Reaction completed after around 2hrs

# %% [markdown]
# Yield is 54mg. Lost too much

# %%
equi_pal(200u"mg")
# Out:
# m6523.809523809524 g mol^-1
# DimensionError: mL and mL mol^-1 are not dimensionally compatible.
#
#
#
# Stacktrace:
#
#  [1] #s103#141
#
#    @ ~/.julia/packages/Unitful/nwwOk/src/conversion.jl:28 [inlined]
#
#  [2] var"#s103#141"(::Any, s::Any, t::Any)
#
#    @ Unitful ./none:0
#
#  [3] (::Core.GeneratedFunctionStub)(::UInt64, ::LineNumberNode, ::Any, ::Vararg{Any})
#
#    @ Core ./boot.jl:707
#
#  [4] uconvert(a::Unitful.FreeUnits{(mL,), 𝐋^3, nothing}, x::Quantity{Float64, 𝐋^3 𝐍^-1, Unitful.FreeUnits{(mL, mol^-1), 𝐋^3 𝐍^-1, nothing}})
#
#    @ Unitful ~/.julia/packages/Unitful/nwwOk/src/conversion.jl:93
#
#  [5] FreeUnits
#
#    @ ~/.julia/packages/Unitful/nwwOk/src/types.jl:110 [inlined]
#
#  [6] |>(x::Quantity{Float64, 𝐋^3 𝐍^-1, Unitful.FreeUnits{(mL, mol^-1), 𝐋^3 𝐍^-1, nothing}}, f::Unitful.FreeUnits{(mL,), 𝐋^3, nothing})
#
#    @ Base ./operators.jl:926
#
#  [7] equi_pal(m_ralox::Quantity{Int64, 𝐌, Unitful.FreeUnits{(mg,), 𝐌, nothing}})
#
# ...

# %% [markdown]
# need to inject

# %%
m_ralox_mono = 13.9u"mg"
m_e2_enanthate = 5u"mg"
# Out:
# 5 mg

# %% [markdown]
# used 50uL EtOH and 50uL EtAc

# %% [markdown]
# Annoyingly cloudy until I added 50uL DMSO

# %% [markdown]
# Mild injection site pain. Maybe EtOH needs to be reduced

# %% [markdown]
# DMSO causes syringe piston to swell. Maybe I should just make a suspension with EtAc dispersed in oil.

# %% [markdown]
# refer to https://en.wikipedia.org/wiki/Paliperidone
#
# Palmitate ester can reach 139days in half life. So I can't be sure about half life of ralox-monopalmitate
#
# But ralox is antagonistic in HPA, E2 is agonistic. This may derive some information.

# %%
yield = 195u"mg"
# Out:
# 195 mg

# %%
using Symbolics

# %%
@variables x y
# Out:
# 2-element Vector{Num}:
#  x
#  y

# %%
x ~ 0.05
eq = x * 0.9 / 274 ~ y * 0.72 / 101
# Out:
# 0.00016423357664233578 ~ 0.007128712871287128y

# %%
Symbolics.symbolic_linear_solve([eq], [y])
# Out:
# 1-element Vector{Float64}:
#  0.023038321167883215

# %%
function equi_pal(m_ralox)
    ralox = 473u"g/mol"
    palmi = 274u"g/mol"
    trieth = 101u"g/mol"
    n = m_ralox / ralox
    println("m_pal_cl ", palmi * n)
    println("v_pal_cl ", (palmi * n / 0.9u"g/ml" |> u"mL"))
    println("m_base ", trieth * n)
    println("v_base ", (trieth * n / 0.72u"g/ml" |> u"mL"))
end
# Out:
# equi_pal (generic function with 1 method)

# %%
equi_pal(200u"mg")
# Out:
# m_pal_cl 115.85623678646935 mg
# v_pal_cl 0.12872915198496593 mL
# m_base 42.706131078224104 mg
# v_base 0.05931407094197792 mL

# %% [markdown]
# 2methf, 10.782mg

# %% [markdown]
# pal, 120.5mg

# %% [markdown]
# tri, 47mg

# %% [markdown]
# Added Cyclohexane as cosolvent to the 2methf
